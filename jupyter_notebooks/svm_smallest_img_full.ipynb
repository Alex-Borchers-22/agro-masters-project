# %%
# load in csvOut.csv data (holds image name & classification)
import csv
import os #to get all picture in directory
from PIL import Image #to open images
import numpy as np #load in numpy module
import sys

# loads in full csvOut data (name & classification)
with open('..//annotations_handheld.csv', newline='') as csvfile:
    cls_full = list(csv.reader(csvfile))

# %%
# Get the list of all files in directory
path = "..//images_handheld_resized"
dir_list = os.listdir(path)

# Initialize dictionaries to hold bitmap information for each image
rgb = {}
rgb_list = []
cls = []

# loop through files and get bit map for each (save as object where filename => bitmap for r,g,b)
for file in cls_full:
    
    # push classification to list
    cls.append(file[1])
    
    # method found https://stackoverflow.com/questions/46385999/transform-an-image-to-a-bitmap
    img = Image.open(path + "\\" + file[0])
    
    # resize image
    small_img = img.resize((600, 400))
    smaller_img = img.resize((300, 200))
    smallest_img = img.resize((120, 80))
    ary = np.array(smallest_img)
    
    # Save all 3 together
    rgb[file[0]] = ary
    
    # Split the three channels
    #r[file], g[file], b[file] = np.split(ary,3,axis=2)
    
    # flatten out to 1 array
    rgb[file[0]]=rgb[file[0]].reshape(-1)
    rgb_list.append(rgb[file[0]])
    
    # convert array to string
    #rgb_string[file] = np.array2string(rgb[file], precision=2, separator=',', suppress_small=True)

# %%
# convert bitmaps to indexed np array
rgb_arr = np.array([rgb[row] for row in rgb])
rgb_arr2 = np.array(rgb_list)

# convert classifications to numpy array
cls_np = np.array(cls)

# %%
len(cls_np)
# Out:
# 7699

# %%
# Training model (load necessary libraries)
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.model_selection import GridSearchCV

#split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(rgb_arr2, cls_np, test_size=0.2)

# %%
# https://www.geeksforgeeks.org/svm-hyperparameter-tuning-using-gridsearchcv-ml/
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
 
# use gridsearchcv to optimize hyperparameters    
clf = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3)

# Train SVM Model
clf.fit(X_train, y_train.ravel())

# Evaluate the model
accuracy = clf.score(X_test, y_test)
print("Accuracy: ", accuracy)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.901 total time= 2.6min
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.902 total time= 2.9min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [41], in <cell line: 11>()
#       8 clf = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3)
#      10 # Train SVM Model
# ---> 11 clf.fit(X_train, y_train.ravel())
#      13 # Evaluate the model
#      14 accuracy = clf.score(X_test, y_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~\anaconda3\lib\site-packages\sklearn\svm\_base.py:255, in BaseLibSVM.fit(self, X, y, sample_weight)
#     252     print("[LibSVM]", end="")
#     254 seed = rnd.randint(np.iinfo("i").max)
# --> 255 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     256 # see comment on the other call to np.iinfo in this file
#     258 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~\anaconda3\lib\site-packages\sklearn\svm\_base.py:315, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     302 libsvm.set_verbosity_wrap(self.verbose)
#     304 # we don't pass **self.get_params() to allow subclasses to
#     305 # add other parameters to __init__
#     306 (
#     307     self.support_,
#     308     self.support_vectors_,
#     309     self._n_support,
#     310     self.dual_coef_,
#     311     self.intercept_,
#     312     self._probA,
#     313     self._probB,
#     314     self.fit_status_,
# --> 315 ) = libsvm.fit(
#     316     X,
#     317     y,
#     318     svm_type=solver_type,
#     319     sample_weight=sample_weight,
#     320     class_weight=self.class_weight_,
#     321     kernel=kernel,
#     322     C=self.C,
#     323     nu=self.nu,
#     324     probability=self.probability,
#     325     degree=self.degree,
#     326     shrinking=self.shrinking,
#     327     tol=self.tol,
#     328     cache_size=self.cache_size,
#     329     coef0=self.coef0,
#     330     gamma=self._gamma,
#     331     epsilon=self.epsilon,
#     332     max_iter=self.max_iter,
#     333     random_seed=random_seed,
#     334 )
#     336 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
# https://medium.com/analytics-vidhya/image-classification-using-machine-learning-support-vector-machine-svm-dc7a0ec92e01
# defining parameter range
param_grid={
    'C':[0.1,10],
    'gamma':[0.0001,0.1],
    'kernel':['sigmoid','rbf', 'poly', 'linear']
}

# Initialize SVC model & pass param grid options to gridsearchcv
clf = GridSearchCV(svm.SVC(probability=True),param_grid, refit = True, verbose = 3)
#clf = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3) # possible 2nd options from other research 

# Train SVM Model
clf.fit(X_train, y_train.ravel())

# Evaluate the model
accuracy = clf.score(X_test, y_test)
print("Accuracy: ", accuracy)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.586 total time=   0.4s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.571 total time=   0.4s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.571 total time=   0.4s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.571 total time=   0.4s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.586 total time=   0.7s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.571 total time=   0.7s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.571 total time=   0.7s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.571 total time=   0.7s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.571 total time=   0.7s
# [CV 1/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.586 total time=   0.5s
# [CV 2/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.643 total time=   0.6s
# [CV 4/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.536 total time=   0.6s
# [CV 5/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.586 total time=   0.5s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.500 total time=   0.6s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.536 total time=   0.7s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.464 total time=   0.5s
# [CV 1/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.586 total time=   0.4s
# [CV 2/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.571 total time=   0.4s
# [CV 3/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.571 total time=   0.4s
# [CV 4/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.571 total time=   0.4s
# [CV 5/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.571 total time=   0.4s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.586 total time=   0.8s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.571 total time=   0.9s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.571 total time=   0.8s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.571 total time=   0.8s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.571 total time=   0.8s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.586 total time=   0.6s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.571 total time=   0.6s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.643 total time=   0.6s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.536 total time=   0.9s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.607 total time=   1.1s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.586 total time=   0.7s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.571 total time=   0.7s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.500 total time=   0.6s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.536 total time=   0.6s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.464 total time=   0.6s
# [CV 1/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.586 total time=   0.5s
# [CV 2/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.571 total time=   0.6s
# [CV 3/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.571 total time=   0.5s
# [CV 4/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.571 total time=   0.4s
# [CV 5/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.571 total time=   0.5s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.586 total time=   0.9s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.571 total time=   0.9s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.571 total time=   0.9s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.571 total time=   0.9s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.571 total time=   0.9s
# [CV 1/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.586 total time=   0.9s
# [CV 2/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.571 total time=   0.8s
# [CV 3/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.643 total time=   0.8s
# [CV 4/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.536 total time=   0.8s
# [CV 5/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.607 total time=   0.7s
# [CV 1/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.586 total time=   0.7s
# [CV 2/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.571 total time=   0.7s
# [CV 3/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.500 total time=   0.8s
# [CV 4/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.536 total time=   0.7s
# [CV 5/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.464 total time=   0.8s
# [CV 1/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.586 total time=   0.8s
# [CV 2/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.571 total time=   0.9s
# [CV 3/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.571 total time=   1.3s
# [CV 4/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.571 total time=   0.6s
# [CV 5/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.571 total time=   0.6s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.586 total time=   1.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.571 total time=   1.1s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.571 total time=   1.2s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.571 total time=   1.2s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.571 total time=   1.1s
# [CV 1/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.586 total time=   0.7s
# [CV 2/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.571 total time=   0.8s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.643 total time=   1.1s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.536 total time=   0.8s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.607 total time=   1.1s
# [CV 1/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.586 total time=   1.1s
# [CV 2/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.571 total time=   1.1s
# [CV 3/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.500 total time=   1.3s
# [CV 4/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.536 total time=   1.1s
# [CV 5/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.464 total time=   1.2s
# Accuracy:  0.7222222222222222

# %%
# https://medium.com/analytics-vidhya/image-classification-using-machine-learning-support-vector-machine-svm-dc7a0ec92e01
# defining parameter range
param_grid = {
    'C': [0.1, 1, 10],              # regularization parameter
    'degree': [2, 3, 4],            # degree of the polynomial kernel
    'coef0': [0, 1, 2],             # independent term in kernel function
    'gamma': ['scale', 'auto'],     # kernel coefficient
    'kernel': ['poly']
}

# Initialize SVC model & pass param grid options to gridsearchcv
clf = GridSearchCV(svm.SVC(probability=True),param_grid, refit = True, verbose = 3)
#clf = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3) # possible 2nd options from other research 

# Train SVM Model
clf.fit(X_train, y_train.ravel())

# Evaluate the model
accuracy = clf.score(X_test, y_test)
print("Accuracy: ", accuracy)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5] END C=0.1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.690 total time=   0.6s
# [CV 2/5] END C=0.1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.429 total time=   0.5s
# [CV 4/5] END C=0.1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.714 total time=   0.5s
# [CV 1/5] END C=0.1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.586 total time=   0.4s
# [CV 2/5] END C=0.1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.643 total time=   0.5s
# [CV 4/5] END C=0.1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.679 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=0.1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.690 total time=   0.5s
# [CV 2/5] END C=0.1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=0.1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.643 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.679 total time=   0.5s
# [CV 1/5] END C=0.1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.621 total time=   0.5s
# [CV 2/5] END C=0.1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=0.1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=0.1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.655 total time=   0.5s
# [CV 2/5] END C=0.1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=0.1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.6s
# [CV 5/5] END C=0.1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.536 total time=   0.5s
# [CV 1/5] END C=0.1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.655 total time=   0.5s
# [CV 2/5] END C=0.1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=0.1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.6s
# [CV 5/5] END C=0.1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.7s
# [CV 1/5] END C=0.1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.724 total time=   0.6s
# [CV 2/5] END C=0.1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.571 total time=   0.6s
# [CV 3/5] END C=0.1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.393 total time=   0.6s
# [CV 4/5] END C=0.1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.679 total time=   0.7s
# [CV 5/5] END C=0.1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.750 total time=   0.9s
# [CV 1/5] END C=0.1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.586 total time=   0.7s
# [CV 2/5] END C=0.1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.536 total time=   0.7s
# [CV 3/5] END C=0.1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.643 total time=   0.7s
# [CV 4/5] END C=0.1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.679 total time=   0.8s
# [CV 5/5] END C=0.1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=0.1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.655 total time=   0.6s
# [CV 2/5] END C=0.1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.536 total time=   0.6s
# [CV 3/5] END C=0.1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 4/5] END C=0.1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=0.1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.643 total time=   0.6s
# [CV 1/5] END C=0.1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=0.1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=0.1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=0.1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.655 total time=   0.5s
# [CV 2/5] END C=0.1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.6s
# [CV 4/5] END C=0.1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.8s
# [CV 1/5] END C=0.1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.655 total time=   0.8s
# [CV 2/5] END C=0.1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.8s
# [CV 3/5] END C=0.1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.9s
# [CV 4/5] END C=0.1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.7s
# [CV 5/5] END C=0.1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.9s
# [CV 1/5] END C=0.1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.655 total time=   0.9s
# [CV 2/5] END C=0.1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.8s
# [CV 3/5] END C=0.1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.429 total time=   0.6s
# [CV 4/5] END C=0.1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.7s
# [CV 5/5] END C=0.1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.714 total time=   0.7s
# [CV 1/5] END C=0.1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.586 total time=   0.6s
# [CV 2/5] END C=0.1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.643 total time=   0.5s
# [CV 4/5] END C=0.1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=0.1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=0.1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=0.1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.536 total time=   0.6s
# [CV 3/5] END C=0.1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.643 total time=   0.7s
# [CV 4/5] END C=0.1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.679 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.7s
# [CV 1/5] END C=0.1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=0.1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.571 total time=   0.6s
# [CV 3/5] END C=0.1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 4/5] END C=0.1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=0.1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=0.1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 4/5] END C=0.1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.643 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.6s
# [CV 1/5] END C=0.1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.655 total time=   0.6s
# [CV 2/5] END C=0.1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.6s
# [CV 3/5] END C=0.1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=0.1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 5/5] END C=0.1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 1/5] END C=1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.621 total time=   0.5s
# [CV 2/5] END C=1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=1, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.643 total time=   0.6s
# [CV 1/5] END C=1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.586 total time=   0.7s
# [CV 2/5] END C=1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.536 total time=   0.6s
# [CV 3/5] END C=1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.643 total time=   0.5s
# [CV 4/5] END C=1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.679 total time=   0.5s
# [CV 5/5] END C=1, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.621 total time=   0.5s
# [CV 2/5] END C=1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 5/5] END C=1, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.621 total time=   0.5s
# [CV 2/5] END C=1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=1, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.655 total time=   0.5s
# [CV 2/5] END C=1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 5/5] END C=1, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 1/5] END C=1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.655 total time=   0.5s
# [CV 2/5] END C=1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 5/5] END C=1, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.6s
# [CV 1/5] END C=1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.586 total time=   0.5s
# [CV 2/5] END C=1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.536 total time=   0.7s
# [CV 3/5] END C=1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 4/5] END C=1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=1, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.586 total time=   0.5s
# [CV 2/5] END C=1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.643 total time=   0.5s
# [CV 4/5] END C=1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.679 total time=   0.5s
# [CV 5/5] END C=1, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.643 total time=   0.5s
# [CV 4/5] END C=1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.679 total time=   0.5s
# [CV 5/5] END C=1, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.621 total time=   0.5s
# [CV 2/5] END C=1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=1, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.655 total time=   0.5s
# [CV 2/5] END C=1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=1, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 1/5] END C=1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.655 total time=   0.5s
# [CV 2/5] END C=1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.7s
# [CV 5/5] END C=1, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 1/5] END C=1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.586 total time=   0.5s
# [CV 2/5] END C=1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 4/5] END C=1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=1, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.586 total time=   0.5s
# [CV 2/5] END C=1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.536 total time=   0.6s
# [CV 3/5] END C=1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.643 total time=   0.6s
# [CV 4/5] END C=1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=1, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.607 total time=   0.7s
# [CV 1/5] END C=1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.643 total time=   0.5s
# [CV 4/5] END C=1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=1, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.621 total time=   0.5s
# [CV 2/5] END C=1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 5/5] END C=1, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.621 total time=   0.5s
# [CV 2/5] END C=1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.643 total time=   0.6s
# [CV 5/5] END C=1, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.6s
# [CV 1/5] END C=1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.655 total time=   0.6s
# [CV 2/5] END C=1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 5/5] END C=1, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 1/5] END C=10, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.586 total time=   0.5s
# [CV 2/5] END C=10, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.536 total time=   0.6s
# [CV 3/5] END C=10, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.643 total time=   0.6s
# [CV 4/5] END C=10, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=10, coef0=0, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=10, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.586 total time=   0.8s
# [CV 2/5] END C=10, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.536 total time=   0.6s
# [CV 3/5] END C=10, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.643 total time=   0.6s
# [CV 4/5] END C=10, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=10, coef0=0, degree=2, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=10, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=10, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=10, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 4/5] END C=10, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 5/5] END C=10, coef0=0, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=10, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=10, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=10, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 4/5] END C=10, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 5/5] END C=10, coef0=0, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 1/5] END C=10, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.655 total time=   0.6s
# [CV 2/5] END C=10, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.7s
# [CV 3/5] END C=10, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=10, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 5/5] END C=10, coef0=0, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.6s
# [CV 1/5] END C=10, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.655 total time=   0.5s
# [CV 2/5] END C=10, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=10, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=10, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.6s
# [CV 5/5] END C=10, coef0=0, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.6s
# [CV 1/5] END C=10, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.586 total time=   0.5s
# [CV 2/5] END C=10, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=10, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=10, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.679 total time=   0.5s
# [CV 5/5] END C=10, coef0=1, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.7s
# [CV 1/5] END C=10, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.586 total time=   0.6s
# [CV 2/5] END C=10, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=10, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.643 total time=   0.6s
# [CV 4/5] END C=10, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=10, coef0=1, degree=2, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=10, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.621 total time=   0.7s
# [CV 2/5] END C=10, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.571 total time=   0.6s
# [CV 3/5] END C=10, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.643 total time=   0.5s
# [CV 4/5] END C=10, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=10, coef0=1, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=10, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.621 total time=   0.5s
# [CV 2/5] END C=10, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=10, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=10, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=10, coef0=1, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=10, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.655 total time=   0.6s
# [CV 2/5] END C=10, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=10, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=10, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 5/5] END C=10, coef0=1, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.5s
# [CV 1/5] END C=10, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.655 total time=   0.5s
# [CV 2/5] END C=10, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 3/5] END C=10, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=10, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 5/5] END C=10, coef0=1, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 1/5] END C=10, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.586 total time=   0.5s
# [CV 2/5] END C=10, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=10, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.5s
# [CV 4/5] END C=10, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.679 total time=   0.5s
# [CV 5/5] END C=10, coef0=2, degree=2, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=10, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.586 total time=   0.5s
# [CV 2/5] END C=10, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.536 total time=   0.5s
# [CV 3/5] END C=10, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.643 total time=   0.5s
# [CV 4/5] END C=10, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=10, coef0=2, degree=2, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=10, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.621 total time=   0.5s
# [CV 2/5] END C=10, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.571 total time=   0.6s
# [CV 3/5] END C=10, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.643 total time=   0.6s
# [CV 4/5] END C=10, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.679 total time=   0.6s
# [CV 5/5] END C=10, coef0=2, degree=3, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=10, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=10, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.571 total time=   0.6s
# [CV 3/5] END C=10, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 4/5] END C=10, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 5/5] END C=10, coef0=2, degree=3, gamma=auto, kernel=poly;, score=0.607 total time=   0.6s
# [CV 1/5] END C=10, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.621 total time=   0.6s
# [CV 2/5] END C=10, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.7s
# [CV 3/5] END C=10, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.607 total time=   0.6s
# [CV 4/5] END C=10, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.643 total time=   0.6s
# [CV 5/5] END C=10, coef0=2, degree=4, gamma=scale, kernel=poly;, score=0.571 total time=   0.6s
# [CV 1/5] END C=10, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.655 total time=   0.6s
# [CV 2/5] END C=10, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.6s
# [CV 3/5] END C=10, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# [CV 4/5] END C=10, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.6s
# [CV 5/5] END C=10, coef0=2, degree=4, gamma=auto, kernel=poly;, score=0.571 total time=   0.5s
# Accuracy:  0.5833333333333334

# %%
# https://medium.com/analytics-vidhya/image-classification-using-machine-learning-support-vector-machine-svm-dc7a0ec92e01
# defining parameter range
param_grid = {
    'C': [0.1, 1, 10],      # regularization parameter
    'loss': ['hinge', 'squared_hinge'],    # type of loss function to use
    'max_iter': [1000, 5000, 10000],       # maximum number of iterations
    'kernel': ['linear']
}

# Initialize SVC model & pass param grid options to gridsearchcv
clf = GridSearchCV(svm.SVC(probability=True), param_grid, refit = True, verbose = 3)
#clf = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3) # possible 2nd options from other research 

# Train SVM Model
clf.fit(X_train, y_train.ravel())

# Evaluate the model
accuracy = clf.score(X_test, y_test)
print("Accuracy: ", accuracy)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END C=0.1, kernel=linear, max_iter=1000;, score=0.586 total time=   0.6s
# [CV 2/5] END C=0.1, kernel=linear, max_iter=1000;, score=0.571 total time=   0.6s
# [CV 3/5] END C=0.1, kernel=linear, max_iter=1000;, score=0.500 total time=   0.5s
# [CV 4/5] END C=0.1, kernel=linear, max_iter=1000;, score=0.536 total time=   0.5s
# [CV 5/5] END C=0.1, kernel=linear, max_iter=1000;, score=0.464 total time=   0.5s
# [CV 1/5] END C=0.1, kernel=linear, max_iter=5000;, score=0.586 total time=   0.6s
# [CV 2/5] END C=0.1, kernel=linear, max_iter=5000;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, kernel=linear, max_iter=5000;, score=0.500 total time=   0.5s
# [CV 4/5] END C=0.1, kernel=linear, max_iter=5000;, score=0.536 total time=   0.4s
# [CV 5/5] END C=0.1, kernel=linear, max_iter=5000;, score=0.464 total time=   0.5s
# [CV 1/5] END C=0.1, kernel=linear, max_iter=10000;, score=0.586 total time=   0.5s
# [CV 2/5] END C=0.1, kernel=linear, max_iter=10000;, score=0.571 total time=   0.5s
# [CV 3/5] END C=0.1, kernel=linear, max_iter=10000;, score=0.500 total time=   0.5s
# [CV 4/5] END C=0.1, kernel=linear, max_iter=10000;, score=0.536 total time=   0.5s
# [CV 5/5] END C=0.1, kernel=linear, max_iter=10000;, score=0.464 total time=   0.7s
# [CV 1/5] END .C=1, kernel=linear, max_iter=1000;, score=0.586 total time=   0.5s
# [CV 2/5] END .C=1, kernel=linear, max_iter=1000;, score=0.571 total time=   0.5s
# [CV 3/5] END .C=1, kernel=linear, max_iter=1000;, score=0.500 total time=   0.6s
# [CV 4/5] END .C=1, kernel=linear, max_iter=1000;, score=0.536 total time=   0.5s
# [CV 5/5] END .C=1, kernel=linear, max_iter=1000;, score=0.464 total time=   0.5s
# [CV 1/5] END .C=1, kernel=linear, max_iter=5000;, score=0.586 total time=   0.5s
# [CV 2/5] END .C=1, kernel=linear, max_iter=5000;, score=0.571 total time=   0.5s
# [CV 3/5] END .C=1, kernel=linear, max_iter=5000;, score=0.500 total time=   0.5s
# [CV 4/5] END .C=1, kernel=linear, max_iter=5000;, score=0.536 total time=   0.5s
# [CV 5/5] END .C=1, kernel=linear, max_iter=5000;, score=0.464 total time=   0.5s
# [CV 1/5] END C=1, kernel=linear, max_iter=10000;, score=0.586 total time=   0.9s
# [CV 2/5] END C=1, kernel=linear, max_iter=10000;, score=0.571 total time=   0.7s
# [CV 3/5] END C=1, kernel=linear, max_iter=10000;, score=0.500 total time=   0.6s
# [CV 4/5] END C=1, kernel=linear, max_iter=10000;, score=0.536 total time=   0.6s
# [CV 5/5] END C=1, kernel=linear, max_iter=10000;, score=0.464 total time=   0.6s
# [CV 1/5] END C=10, kernel=linear, max_iter=1000;, score=0.586 total time=   0.5s
# [CV 2/5] END C=10, kernel=linear, max_iter=1000;, score=0.571 total time=   0.6s
# [CV 3/5] END C=10, kernel=linear, max_iter=1000;, score=0.500 total time=   0.6s
# [CV 4/5] END C=10, kernel=linear, max_iter=1000;, score=0.536 total time=   0.5s
# [CV 5/5] END C=10, kernel=linear, max_iter=1000;, score=0.464 total time=   0.6s
# [CV 1/5] END C=10, kernel=linear, max_iter=5000;, score=0.586 total time=   0.5s
# [CV 2/5] END C=10, kernel=linear, max_iter=5000;, score=0.571 total time=   0.5s
# [CV 3/5] END C=10, kernel=linear, max_iter=5000;, score=0.500 total time=   0.5s
# [CV 4/5] END C=10, kernel=linear, max_iter=5000;, score=0.536 total time=   0.6s
# [CV 5/5] END C=10, kernel=linear, max_iter=5000;, score=0.464 total time=   0.5s
# [CV 1/5] END C=10, kernel=linear, max_iter=10000;, score=0.586 total time=   0.5s
# [CV 2/5] END C=10, kernel=linear, max_iter=10000;, score=0.571 total time=   0.5s
# [CV 3/5] END C=10, kernel=linear, max_iter=10000;, score=0.500 total time=   0.6s
# [CV 4/5] END C=10, kernel=linear, max_iter=10000;, score=0.536 total time=   0.5s
# [CV 5/5] END C=10, kernel=linear, max_iter=10000;, score=0.464 total time=   0.6s
# Accuracy:  0.75
